# %% [markdown]
# BT19ECE040 \
# Divyansh Kumar
#
# Create two images one with a white circle at center and another with a white rentangle at center and performe all logical gate operations on both images and display the output images.

# %%
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Task 1

# %%
c_img = Image.new(mode= 'L', size=(200, 200), color = 0)
circle = ImageDraw.Draw(c_img)
circle.ellipse([(40, 40), (160, 160)], fill = 'white', outline='white')

# %%
plt.imshow(c_img, cmap = 'gray')

# %% [markdown]
# # Task 2

# %%
r_img = Image.new(mode= 'L', size=(200, 200), color = 0)
rectangle = ImageDraw.Draw(r_img)
rectangle.rectangle([(30,50), (170,150)], fill = 'white', outline= 'white')

# %%
plt.imshow(r_img, cmap='gray')

# %% [markdown]
# # Task 3

# %%
c_img = np.asarray(c_img)
r_img = np.asarray(r_img)

# %%
# AND gate
and_img = np.zeros((200, 200))
for i in range(200):
    for j in range(200):
        if(c_img[i,j] == 255 and r_img[i,j] == 255):
            and_img[i,j] = 255

plt.imshow(and_img, cmap='gray')

# %%
# OR gate
or_img = np.zeros((200, 200))
for i in range(200):
    for j in range(200):
        if(c_img[i,j] == 255 or r_img[i,j] == 255):
            or_img[i,j] = 255

plt.imshow(or_img, cmap='gray')

# %%
#NAND Gate
nand_img = np.zeros((200, 200))
for i in range(200):
    for j in range(200):
        if(not(c_img[i,j] == 255 and r_img[i,j] == 255)):
            nand_img[i,j] = 255

plt.imshow(nand_img, cmap='gray')

# %%
# NOR gate
nor_img = np.zeros((200, 200))
for i in range(200):
    for j in range(200):
        if(not(c_img[i,j] == 255 or r_img[i,j] == 255)):
            nor_img[i,j] = 255

plt.imshow(nor_img, cmap='gray')

# %%
# XOR gate
xor_img = np.zeros((200, 200))
for i in range(200):
    for j in range(200):
        if(c_img[i,j] != r_img[i,j]):
            xor_img[i,j] = 255

plt.imshow(xor_img, cmap='gray')

# %%
#NOT gate
not_img = np.zeros((200, 200))
for i in range(200):
    for j in range(200):
        if(xor_img[i,j] == 0):
            not_img[i,j] = 255

plt.imshow(not_img, cmap='gray')

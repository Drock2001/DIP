# %% [markdown]
# BT19ECE040 \
# Divyansh Kumar
#
# Assignment 1: Take a passport size photo of yours and perform the following: \
# a.  Convert to gray scale \
# b.  Conver to binary \
# c.  Add a and b \
# d.  Add 20 to a

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("msELlJ2R_400x400.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %% [markdown]
# # Task 1

# %%
gray = 0.2989*img[:,:,0] + 0.5870*img[:,:,1] + 0.1140*img[:,:,2]

# %%
plt.imshow(gray, cmap='gray')

# %% [markdown]
# # Task2

# %%
threshold = 127
bin = np.zeros((img.shape[0], img.shape[1]))

# %%
for i in range(len(gray)):
    for j in range(len(gray[i])):
        if(gray[i,j] > threshold):
            bin[i,j] = 1

# %%
plt.imshow(bin, cmap='binary')

# %% [markdown]
# # Task 3

# %%
bin_gray = bin + gray

# %%
plt.imshow(bin_gray, cmap='gray')

# %% [markdown]
# # Task 4

# %%
gray_20 = gray + 20

# %%
plt.imshow(gray_20, cmap='gray')
